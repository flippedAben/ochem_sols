# %% [markdown]
# # Solutions to 1.E
#
# Exercises can be found on [this LibreTexts page][1].
#
# __I urge you to try the problems yourself first before looking at solutions.__
#
# _Note: the following solutions may be incorrect._
#
# [1]: https://chem.libretexts.org/Bookshelves/Organic_Chemistry/Book%3A_Basic_Principles_of_Organic_Chemistry_(Roberts_and_Caserio)/01%3A_Introduction_to_Organic_Chemistry/1.0E%3A_1.E%3A_Introduction_to_Organic_Chemistry_(Exercises)
#
# $$\require{mhchem}$$

# %%
from rdkit import Chem

# %% [markdown]
# ## 1-1
#
# I assume there is a typo in the problem, and that the author means $\ce{C2H2Br4}$, not $\ce{CH2Br4}$.
#
# There are two isomers:

# %%
isomer_a = Chem.MolFromSmiles(('C' + '(Br)' * 2) * 2)
isomer_a

# %%
isomer_b = Chem.MolFromSmiles('C(Br)' + 'C' + '(Br)' * 3)
isomer_b

# %% [markdown]
# Suppose we have some $\ce{C2H2Br4}$, and we want to know which isomer it is using the substitution method. The key idea is to exploit the symmetry that `isomer_a` has, but `isomer_b` does not. We apply a reaction that substitutes a $\ce{Br}$ with a $\ce{H}$. Then, after the substitution reaction, `isomer_b` will have two possible products: `prod_1` and `prod_2`. `isomer_a` will one have one possible product: `prod_2`.

# %%
prod_1 = Chem.MolFromSmiles('C' + 'C' + '(Br)' * 3)
prod_1

# %%
prod_2 = Chem.MolFromSmiles('C(Br)' + 'C' + '(Br)' * 2)
prod_2

# %% [markdown]
# ## 1-2

# %%
print('TODO')
# Out:
# TODO
